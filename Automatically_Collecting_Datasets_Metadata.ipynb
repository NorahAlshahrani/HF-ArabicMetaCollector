# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "Table_1v3.png")
# Out:
# <img src="Table_1v3.png"/>

# %%
from functions import *

# %% [markdown]
# # Listing tasks (using categories):

# %%
task_mapping = {
    "Q&A": "question-answering",
    "Reasoning & Multi-step Thinking": "reasoning",
    "Summarization": "summarization",
    "Cultural Alignment": "cultural-aligned",
    "Dialog/Conversation": "conversational",
    "Personal Ownership/System Prompt": "System Prompt",  
    "Robustness & Safety": "Safety",
    "Function Call": "function-call",  
    "Ethics, Bias, and Fairness": "bias-and-fairness",
    "Code Generation": "Code Generation",
    "Official Documentation": "documentation",
    "Translation": "translation"
}

all_datasets_by_task_categories = get_arabic_datasets_by_task_categories(task_mapping)
all_datasets_by_task_categories
# Out:
#             Task                            Dataset ID  Likes  Downloads  \
# 0            Q&A                         facebook/mlqa     42       1341
# 1            Q&A       google-research-datasets/tydiqa     32       1386
# 2            Q&A                     facebook/belebele    113      12822
# 3            Q&A                       nayeon212/BLEnD     10        366
# 4            Q&A                  stanford-oval/ccnews     21       3295
# ..           ...                                   ...    ...        ...
# 371  Translation         taha-alnasser/ArzEn-CodeMixed      0         14
# 372  Translation           Hamzah-Asadullah/TinyDS-20k      1        166
# 373  Translation                 Groovy-123/deep-think      1         58
# 374  Translation          liboaccn/nmt-parallel-corpus      1        104
# 375  Translation  freococo/quran_multilingual_parallel      0        123
#
#                 Last Modified       License  Models  \
# ...

# %%
all_datasets_by_task_categories['Task'].value_counts()
# Out:
# Task
# Q&A              169
# Translation      158
# Summarization     49
# Name: count, dtype: int64

# %%
all_datasets_by_task_categories.to_csv("all_datasets_by_task_categories.csv", index=False)

# %% [markdown]
# # Listing tasks (using keywords):

# %% [markdown]
# ## Cultural Alignment Task

# %%
search_keywords = ["cultural", "culture", "cidar"]
required_tags = ["cultural-aligned"]
required_modality = "modality:text"

Alignment_df = get_arabic_datasets_by_keywords(search_keywords, required_tags, required_modality)
Alignment_df
# Out:
#                                           Dataset ID  Likes  Downloads  \
# 0                                        arbml/CIDAR     51        239
# 1  FreedomIntelligence/ACVA-Arabic-Cultural-Value...      8        131
# 2                               arbml/CIDAR-EVAL-100      2         44
# 3                                arbml/CIDAR-MCQ-100      4        115
# 4  Omartificial-Intelligence-Space/ILMAAM-Arabic-...      2         32
# 5                                 MBZUAI/ArabCulture     11        747
# 6  HabibaAbderrahim/Tunisian-Proverbs-with-Image-...      0        571
# 7                UBC-NLP/palmx_2025_subtask1_culture      0        142
#
#               Last Modified          License  Models  \
# 0 2025-04-03 08:35:36+00:00       apache-2.0       3
# 1 2023-09-21 12:39:18+00:00       apache-2.0       2
# 2 2024-02-14 15:46:10+00:00       apache-2.0       0
# 3 2024-04-02 14:48:39+00:00       apache-2.0       0
# 4 2025-02-20 17:22:43+00:00       apache-2.0       0
# ...

# %%
Alignment_df.to_csv("Alignment_df.csv", index=False)

# %% [markdown]
# ## Reasoning & Multi-step Thinking Task

# %%
search_keywords = ["Reasoning", "Multi-step reasoning"]
required_tags = []
required_modality = "modality:text"

Reasoning_df = get_arabic_datasets_by_keywords(search_keywords, required_tags, required_modality)
Reasoning_df
# Out:
#                                           Dataset ID  Likes  Downloads  \
# 0                 MohammedNasser/ARabic_Reasoning_QA      5         11
# 1        MohammedNasser/Arabic_Reasoning_Instruct_QA      2         61
# 2  Omartificial-Intelligence-Space/Arabic_Reasoni...      9         75
# 3  lightblue/reasoning-multilingual-R1-Llama-70B-...     36        362
# 4        Jr23xd23/Arabic-Optimized-Reasoning-Dataset      2         32
# 5     Pinkstack/OpenHumanreasoning-multilingual-2.2k      2         42
# 6        miscovery/Math_CoT_Arabic_English_Reasoning     16        137
# 7          beetleware/arabic-reasoning-dataset-logic      8        118
#
#               Last Modified     License  Models Size of downloaded files  \
# 0 2024-09-07 23:00:07+00:00  apache-2.0       1                  UNKNOWN
# 1 2024-09-10 07:30:48+00:00  apache-2.0       1                   112 KB
# 2 2024-12-01 08:13:05+00:00  apache-2.0       4                  2.92 MB
# ...

# %%
Reasoning_df.to_csv("Reasoning_df.csv", index=False)

# %% [markdown]
# ## Dialog/Conversation Task

# %%
search_keywords = ["Dialog", "Conversation"]  
required_tags = []
required_modality = "modality:text"

Dialog_df = get_arabic_datasets_by_keywords(search_keywords, required_tags, required_modality)
Dialog_df
# Out:
#                                   Dataset ID  Likes  Downloads  \
# 0        mohamedemam/Arabic-samsum-dialogsum      1         49
# 1   m-ric/Open_Assistant_Conversation_Chains      6         46
# 2     premio-ai/TheArabicPile_Conversational      1         42
# 3         Mars203020/arabic_medical_dialogue      3        125
# 4                  willwade/AACConversations      0          9
# 5  astroa7m/Conversational_AOU_tutor_dataset      0         11
#
#               Last Modified       License  Models Size of downloaded files  \
# 0 2023-09-11 14:35:29+00:00  cc-by-nc-2.0       1                    14 MB
# 1 2023-11-22 14:37:58+00:00    apache-2.0       0                  30.2 MB
# 2 2024-03-21 21:42:33+00:00  cc-by-nc-4.0       0                  UNKNOWN
# 3 2024-06-29 11:49:41+00:00           mit       0                   460 KB
# 4 2025-05-15 10:37:50+00:00     cc-by-4.0       0                  UNKNOWN
# ...

# %%
Dialog_df.to_csv("Dialog_df.csv", index=False)

# %% [markdown]
# ## Persona Ownership/System Prompt Task

# %%
search_keywords = ["system prompt", "persona"]  
required_tags = []
required_modality = "modality:text"

Persona_df = get_arabic_datasets_by_keywords(search_keywords, required_tags, required_modality)
Persona_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Robustness & Safety Task

# %%
search_keywords = ["Robustness", "Safety", "Toxicity", "jailbreak"]  
required_tags = []
required_modality = "modality:text"

Robustness_df = get_arabic_datasets_by_keywords(search_keywords, required_tags, required_modality)
Robustness_df
# Out:
#                                           Dataset ID  Likes  Downloads  \
# 0            textdetox/multilingual_toxicity_dataset     25        636
# 1             ToxicityPrompts/PolygloToxicityPrompts     11        256
# 2     luizapzbn/from-one-to-many-toxicity-mitigation      0        242
# 3          textdetox/multilingual_toxicity_explained      1        144
# 4                       ToxicityPrompts/PolyGuardMix      1        229
# 5                   ToxicityPrompts/PolyGuardPrompts      0        156
# 6              Malikeh1375/tokenizer-robustness-mmlu      0        179
# 7    Malikeh1375/code-switching-tokenizer-robustness      1        267
# 8  gravitee-io/textdetox-multilingual-toxicity-da...      0         93
#
#               Last Modified     License  Models Size of downloaded files  \
# 0 2025-03-21 18:52:31+00:00  openrail++       8                   6.8 MB
# 1 2024-05-16 07:02:28+00:00        none       0                  UNKNOWN
# ...

# %%
Robustness_df.to_csv("Robustness_df.csv", index=False)

# %% [markdown]
# ## Ethics, Bias, and Fairness Task

# %%
search_keywords = ["Ethics", "Bias", "Fairness"]  
required_tags = []
required_modality = "modality:text"

Ethics_df = get_arabic_datasets_by_keywords(search_keywords, required_tags, required_modality)
Ethics_df
# Out:
#                   Dataset ID  Likes  Downloads             Last Modified  \
# 0  LanguageShades/BiasShades     16        176 2025-05-03 23:25:04+00:00
#
#   License  Models Size of downloaded files Size of downloaded files in bytes  \
# 0    none       0                  UNKNOWN                           unknown
#
#   Size of Parquet files Size of Parquet files in bytes Number of Rows  \
# 0               UNKNOWN                        unknown        unknown
#
#   ArXiv Paper ACL Paper                                        README file  \
# 0        none      none  ---\ntask_categories:\n- text-classification\n...
#
#   README Quality Level  README Quality Score
# 0                 High                     4

# %%
Ethics_df.to_csv("Ethics_df.csv", index=False)

# %% [markdown]
# ## Code Generation Task

# %%
search_keywords = ["code generation"]
required_tags = []
required_modality = "modality:text"

Code_df = get_arabic_datasets_by_keywords(search_keywords, required_tags, required_modality)
Code_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Official Documentation Task

# %%
search_keywords = ["Documentation", "Official Documentation"]
required_tags = []
required_modality = "modality:text"

Documentation_df = get_arabic_datasets_by_keywords(search_keywords, required_tags, required_modality)
Documentation_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Function Call Task

# %%
search_keywords = ["Function Call"]
required_tags = []
required_modality = "modality:text"

Function_df = get_arabic_datasets_by_keywords(search_keywords, required_tags, required_modality)
Function_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Summary:

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "Table_2.png")
# Out:
# <img src="Table_2.png"/>
